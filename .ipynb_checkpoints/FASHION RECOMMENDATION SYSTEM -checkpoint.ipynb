# %% [markdown]
# # FASHION RECOMMENDATION SYSTEM

# %% [markdown]
# Fashion Recommendation System using Image Features: Process We Can Follow
# Building a fashion recommendation system using image features involves several key steps, leveraging both computer vision and machine learning techniques. Below is a detailed process you can follow to build a fashion recommendation system using image features:
#
# 1.Assemble a diverse dataset of fashion items. This dataset should include a wide variety of items with different colours, patterns, styles, and categories.
# 2.Ensure all images are in a consistent format (e.g., JPEG, PNG) and resolution.
# 3.Implement a preprocessing function to prepare images for feature extraction.
# 4.Choose a pre-trained CNN model such as VGG16, ResNet, or InceptionV3. These models, pre-trained on large datasets like ImageNet, are capable of extracting powerful feature representations from images.
# 5.Pass each image through the CNN model to extract features.
# 6.Define a metric for measuring the similarity between feature vectors.
# 7.Rank the dataset images based on their similarity to the input image and recommend the top N items that are most similar.
# 8.Implement a final function that encapsulates the entire process from pre-processing an input image, extracting features, computing similarities, and outputting recommendations.

# %% [markdown]
# # Importing the necessary Python libraries and the dataset:

# %%
from zipfile import ZipFile
import os

zip_file_path = "C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion.zip"
extraction_directory = "C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion"

if not os.path.exists(extraction_directory):
    os.makedirs(extraction_directory)

with ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_directory)

extracted_files = os.listdir(extraction_directory)
print(extracted_files[:10])
# Out:
# ['women-fashion']

# %% [markdown]
# In the above code, a zip file named ‘women fashion.zip’ located at the path: ‘C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women fashion.zip’ on Google Colab is being extracted to a specified directory: ‘C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women_fashion/’. Initially, we check if the extraction directory exists, and if it does not, the directory is created using os.makedirs(). Then, using Python’s ZipFile module, the zip file is opened in read mode, and its contents are extracted to the designated directory.
#
# The zip file contains a directory named women fashion and some metadata used by macOS (__MACOSX). Let’s ignore the macOS metadata and focus on the women fashion directory, listing its contents to understand the types and number of images we have:

# %%
# correcting the path to include the 'women fashion' directory and listing its contents
extraction_directory_updated = os.path.join(extraction_directory, 'women fashion')

# list the files in the updated directory
extracted_files_updated = os.listdir(extraction_directory_updated)
extracted_files_updated[:10], len(extracted_files_updated)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 extraction_directory_updated = os.path.join(extraction_directory, 'women fashion')
#       4 # list the files in the updated directory
# ----> 5 extracted_files_updated = os.listdir(extraction_directory_updated)
#       6 extracted_files_updated[:10], len(extracted_files_updated)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion\\women fashion'

# %% [markdown]
#  let’s have a look at the first image from the dataset:

# %%
from PIL import Image
import matplotlib.pyplot as plt

# function to load and display an image
def display_image(file_path):
    image = Image.open(file_path)
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# display the first image to understand its characteristics
first_image_path = os.path.join(extraction_directory_updated, extracted_files_updated[1])
display_image(first_image_path)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[17], line 13
#      11 # display the first image to understand its characteristics
#      12 first_image_path = os.path.join(extraction_directory_updated, extracted_files_updated[1])
# ---> 13 display_image(first_image_path)
#
# Cell In[17], line 6, in display_image(file_path)
#       5 def display_image(file_path):
# ----> 6     image = Image.open(file_path)
#       7     plt.imshow(image)
#       8     plt.axis('off')
#
# File c:\Users\Shuhaib\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:3247, in open(fp, mode, formats)
#    3244     filename = fp
#    3246 if filename:
# -> 3247     fp = builtins.open(filename, "rb")
#    3248     exclusive_fp = True
#    3250 try:
#
# PermissionError: [Errno 13] Permission denied: 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion\\women-fashion\\__MACOSX'

# %% [markdown]
# Now, we will create a list of all image file paths that will be used later in extracting the features from every image in the dataset:

# %%
import glob

# directory path containing your images
image_directory = 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion'

image_paths_list = [file for file in glob.glob(os.path.join(image_directory, '*.*')) if file.endswith(('.jpg', '.png', '.jpeg', 'webp'))]

# print the list of image file paths
print(image_paths_list)
# Out:
# ['C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\anarkali suit with a long, olive green kurta adorned with intricate embroidery around the neckline and cuffs, paired with matching fitted trousers.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\Anarkali suit with a modern twist.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\Anarkali suit with fitted bodice with a high neckline.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\anarkali suit with lavender in color with intricate white patterns throughout the fabric.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\anarkali suit. It consists of a turquoise skirt with detailed golden embroidery, a multicolored blouse with floral patterns, and an orange dupatta with lace borders.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\beige top adorned with black dots and a green skirt.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\black and white gingham checkered A-line dress with a flared skirt.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\black double-breasted blazer with gold buttons, paired with a mid-length skirt.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\black dress with lace detailing.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\black dress with sparkling details.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\black floral saree.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\black jumpsuit with a diagonal stripe of glittering material running across the body.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\black lace bustier top paired with high-waisted black trousers.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\black off-shoulder dress with belt.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\black top with spaghetti straps and a black skirt adorned with a fringe detail at the hem.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\black top, white trousers.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\black, sequined dress with thin shoulder straps.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\blue dress with a floral pattern.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\bright red kurta with an intricate patterned design.jpg', 'C:/Users/Shuhaib/Downloads/shuaib/Project/DATA_Science/Fashion recommendation/women-fashion/women fashion\\bright red, form-fitting, strapless dress with a high slit on one side revealing part of the leg.jpg', 'C:/Users/Shuhaib/Downloads/shuai ...

# %% [markdown]
# In the above code, the glob module is used to generate a list of file paths for images stored in the directory. The glob.glob function searches for files that match a specified pattern, in this case, *.*, which matches all files within the directory. The list comprehension then filters these files to include only those with specific image file extensions (.jpg, .png, .jpeg, .webp).
#
# It ensures that image_paths_list contains paths to only the image files, excluding any other file types that might be present in the directory.
#
# Now, we will extract features from all the fashion images:

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
import numpy as np

base_model = VGG16(weights='imagenet', include_top=False)
model = Model(inputs=base_model.input, outputs=base_model.output)

def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded = np.expand_dims(img_array, axis=0)
    return preprocess_input(img_array_expanded)

def extract_features(model, preprocessed_img):
    features = model.predict(preprocessed_img)
    flattened_features = features.flatten()
    normalized_features = flattened_features / np.linalg.norm(flattened_features)
    return normalized_features

all_features = []
all_image_names = []

for img_path in image_paths_list:
    preprocessed_img = preprocess_image(img_path)
    features = extract_features(model, preprocessed_img)
    all_features.append(features)
    all_image_names.append(os.path.basename(img_path))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step

# %% [markdown]
# In the above code, a feature extraction process is implemented using the VGG16 model, a popular convolutional neural network pre-trained on the ImageNet dataset, to extract visual features from images stored in image_paths_list.
#
# Initially, the VGG16 model is loaded without its top classification layer (include_top=False), making it suitable for feature extraction rather than classification. Each image path from image_paths_list is processed through a series of steps: the image is loaded and resized to 224×224 pixels to match the VGG16 input size requirements, converted to a NumPy array, and preprocessed to fit the model’s expected input format.

# %% [markdown]
# The preprocessed images are then fed into the VGG16 model to extract features, which are subsequently flattened and normalized to create a consistent feature vector for each image. These feature vectors (all_features) and their corresponding image filenames (all_image_names) are stored, providing a structured dataset for the next steps in building a fashion recommendation system using image features.
#
# Now, I’ll write a function to recommend fashion images based on image features:

# %%
from scipy.spatial.distance import cosine

def recommend_fashion_items_cnn(input_image_path, all_features, all_image_names, model, top_n=4):
    # Pre-process the input image and extract features
    preprocessed_img = preprocess_image(input_image_path)
    input_features = extract_features(model, preprocessed_img)
    
    # Calculate similarities
    similarities = [1 - cosine(input_features, other_feature) for other_feature in all_features]
    
    # Get the input image's basename
    input_image_name = os.path.basename(input_image_path)
    
    # Find the top N similar images, excluding the input image itself
    similar_indices = [idx for idx in np.argsort(similarities)[-top_n-1:] if all_image_names[idx] != input_image_name]
    
    # Display the input image
    plt.figure(figsize=(15, 10))
    plt.subplot(1, top_n + 1, 1)
    plt.imshow(Image.open(input_image_path))
    plt.title("Input Image")
    plt.axis('off')

    # Display similar images
    for i, idx in enumerate(similar_indices[:top_n], start=1):
        image_path = os.path.join(image_directory, all_image_names[idx])
        plt.subplot(1, top_n + 1, i + 1)
        plt.imshow(Image.open(image_path))
        plt.title(f"Recommendation {i}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# In the above code, we defined a function recommend_fashion_items_cnn, which recommends fashion items similar to a given input image using deep learning-based feature extraction. It utilizes the VGG16 model to extract high-dimensional feature vectors from images, capturing their visual essence.
#
# For a specified input image, the function preprocesses the image, extracts its features, and calculates the cosine similarity between this feature vector and those of other images in the dataset (all_features). It ranks these images based on similarity and selects the top N most similar images to recommend, explicitly excluding the input image from being recommended to itself by filtering out its index from the list of similar indices.
#
# In the end, the function will visualize the input image and its recommendations by displaying them.

# %% [markdown]
# to recommend images based on a similar fashion in the input image:

# %%
input_image_path ="C:/Users/Shuhaib/Desktop/WhatsApp Image 2024-09-06 at 10.06.48_1fad80b4.jpg"
recommend_fashion_items_cnn(input_image_path, all_features, image_paths_list, model, top_n=5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 842ms/step

# %%
import joblib

# %%
joblib.dump(all_features, 'fashion_features.pkl')
joblib.dump(all_image_names, 'fashion_image_names.pkl')
# Out:
# ['fashion_image_names.pkl']
